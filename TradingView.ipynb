# %%
import requests
import re
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as ec
import time
import json
import pandas as pd
import datetime

# %%
# initiating the webdriver. Parameter includes the path of the webdriver.
driver = webdriver.Chrome('./assets/chromedriver')
# Out:
# /Users/quangluong/opt/anaconda3/envs/trading/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object

# %%
def getHTMLContent(URL):
    driver.get(URL)
    
    # this is just to ensure that the page is loaded
    time.sleep(5)
    
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    return soup

# %%
URL = "https://www.tradingview.com/"
content = getHTMLContent(URL)

# %%
content.visibility_of_all_elements_located()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/qt/tp1r_fx96gxckrwfgy_p5bn40000gn/T/ipykernel_86240/1972357574.py in <module>
# ----> 1 content.visibility_of_all_elements_located()
#
# TypeError: 'NoneType' object is not callable

# %%
div[data-name="alerts"]
# Out:
# <html class="is-not-authenticated is-not-pro is-not-trial theme-light feature-no-touch feature-no-mobiletouch is-not-trial-available" dir="ltr" lang="en"><head>
# <script async="" nonce="" src="https://www.google-analytics.com/gtm/js?id=GTM-TVZD48S&amp;t=gtag_UA_24278967_1&amp;cid=323444598.1632922171&amp;aip=true" type="text/javascript"></script><script async="" nonce="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script nonce="">
# 		var environment = 'battle';
# 		window.WS_HOST_PING_REQUIRED = true;
# 		window.BUILD_TIME = '2021_09_29-12_50';
# 		window.WEBSOCKET_HOST = 'data.tradingview.com';
# 		window.WEBSOCKET_PRO_HOST = 'prodata.tradingview.com';
# 		window.TradingView = window.TradingView || {};
#
# 	</script>
# <script nonce="">
# 		!function(){"use strict";function t(t,e=!1){const{searchParams:s}=new URL(String(location)),n=function(t){const e=t+"=",s=document.cookie.split(";");for(let t=0;t<s.length;t++){let n=s[t];for(;" "===n.charAt(0);)n=n.substring(1,n.length);if(0===n.indexOf(e))return n.substring(e.length,n.length)}return null}("tv_app")||"";let o="true"===s.get("mobileapp_new"),i="true"===s.get("mobileapp");return e||(o||(o=["android","android_nps"].includes(n)),i||(i="ios"===n)),!("new"!==t&&"any"!==t||!o)||!("new"===t||!i)}const e=()=>{},s="~m~";class n{constructor(t,e={}){this.sessionid=null,this.connected=!1,this._timeout=null,this._base=t,this._options={timeout:6e4,...e}}connect(){this._socket=new WebSocket(this._prepareUrl()),this._socket.onmessage=t=>{if("string"!=typeof t.data)throw new TypeError(`The WebSocket message should be a string. Recieved ${Object.prototype.toString.call(t.data)}`);this._onData(t.data)},this._socket.onclose=this._onClose.bind(this),this._socket.onerror=this._onError.bind(this)}send(t){this._socket&&this._socket.send(this._encode(t))}disconnect(){this._clearIdleTimeout(),this._socket&&(this._socket.onmessage=e,this._socket.onclose=e,this._socket.onerror=e,this._socket.close())}_clearIdleTimeout(){null!==this._timeout&&(clearTimeout(this._timeout),this._timeout=null)}_encode(t){let e,o="";const i=Array.isArray(t)?t:[t],c=i.length;for(let t=0;t<c;t++)e=null===i[t]||void 0===i[t]?"":n._stringify(i[t]),o+=s+e.length+s+e;return o}_decode(t){const e=[];let n,o;do{if(t.substr(0,3)!==s)return e;n="",o="";const i=(t=t.substr(3)).length;for(let e=0;e<i;e++){if(o=Number(t.substr(e,1)),Number(t.substr(e,1))!==o){t=t.substr(n.length+s.length),n=Number(n);break}n+=o}e.push(t.substr(0,n)),t=t.substr(n)}while(""!==t);return e}_onData(t){this._setTimeout();const e=this._decode(t),s=e.length;for(let t=0;t<s;t++)this._onMessage(e[t])}_setTimeout(){this._clearIdleTimeout(),this._timeout=setTimeout(this._onTimeout.bind(this),this._options.timeout)}_onTimeout(){this.disconnect(),this._onDisconnect({code:4e3,reason:"socket.io timeout",wasClean:!1})}_onMessage(t){this.sessionid?this._checkIfHeartbeat(t)?this._onHeartbeat(t.slice(3)):this._checkIfJson(t)?this._base.onMessage(JSON.parse(t.slice(3))):this._base.onMessage(t):(this.sessionid=t,this._onConnect())}_checkIfHeartbeat(t){return this._checkMessageType(t,"h")}_checkIfJson(t){return this._checkMessageType(t,"j")}_checkMessageType(t,e){return t.substr(0,3)==="~"+e+"~"}_onHeartbeat(t){this.send("~h~"+t)}_onConnect(){this.connected=!0,this._base.onConnect()}_onDisconnect(t){this._clear(),this._base.onDisconnect(t),this.sessionid=null}_clear(){this.connected=!1}_prepareUrl(){return`wss://${this._base.host}/socket.io/websocket`+(this.sessionid?"/"+this.sessionid:"")+"?from="+encodeURIComponent(window.location.pathname.slice(1,50))+"&date="+encodeURIComponent(window.BUILD_TIME||"")+(t("any")?"&client=mobile":"")}_onClose(t){this._clearIdleTimeout(),this._onDisconnect(t)}_onError(t){this._clearIdleTimeout(),this._clear(),this._base.emit("error",[t]),this.sessionid=null}static _stringify(t){return"[object Object]"===Object.prototype.toString.call(t)?"~j~"+JSON.stringify(t):String(t)}}class o{constructor(t,e){this.host=t,this.options={connectTimeout:5e3,...e},this._connecting=!1,this._events={},this.transport=this._getTransport()}isConnected(){return!!this.transport&&this.transport.connected}isConnecting(){return this._connecting}connect(){this.isConnected()||(this._connecting&&this.disconnect(),this._connecting=!0,this.transport.connect())}send(t){this.transport&&this.transport.connected&&this.transport.send(t)}disconnect(){this.transport&&this.transport.disconnect()}on(t,e){t in this._events||(this._events[t]=[]),this._events[t].push(e)}offAll(){this._events={}}onMessage(t){this.emit("message",[t])}emit(t,e=[]){if(t in this._events){const s=this._events[t].concat(),n=s.length;for(let t=0;t<n;t++)s[t].apply(this,e)}}onConnect(){this.clear(),this.emit("connect")}onDisconnect(t){this.emit("d ...
# 	</script>
# <meta charset="utf-8"/>
# <meta content="1205990992" property="al:ios:app_store_id"/>
# <meta content="TradingView - trading community, charts and quotes" property="al:ios:app_name"/>
# <title>Access Denied — TradingView</title>
# <meta content="" name="description"/>
# <meta content="TradingView" property="og:site_name"/><meta content="website" property="og:type"/><meta content="" property="og:title"/><meta content="" property="og:description"/><meta content="https://www.tradingview.com/chart/slUnZbCi/" property="og:url"/><meta content="https://www.tradingview.com/static/images/logo-preview.png" property="og:image"/><meta content="630" property="og:image:height"/><meta content="1200" property="og:image:width"/><meta content="https://www.tradingview.com/static/images/logo-preview.png" property="og:image:secure_url"/>
# <meta content="@TradingView" name="twitter:site"/><meta content="summary" name="twitter:card"/><meta content="" name="twitter:title"/><meta content="" name="twitter:description"/><meta content="https://www.tradingview.com/chart/slUnZbCi/" name="twitter:url"/><meta content="https://www.tradingview.com/static/images/logo-preview.png" name="twitter:image"/><meta content="IE=100" http-equiv="X-UA-Compatible"/>
# <link data-locale="en" href="https://www.tradingview.com/chart/slUnZbCi/" rel="link-locale"/><link data-locale="in" href="https://in.tradingview.com/chart/slUnZbCi/" rel="link-locale"/><link data-locale="de_DE" href="https://de.tradingview.com/chart/slUnZbCi/" rel="link-locale"/><link data-locale="fr" href="https://fr.tradingview.com/chart/slUnZbCi/" rel="link-locale"/><link data-locale="es" href="https://es.tradingview.com/chart/slUnZbCi/" rel="link-locale"/><link data-locale="it" href="https://it.tradingview.com/chart/slUnZbCi/" rel="link-locale"/><link data-locale="pl" href="https://pl.tradingview.com/chart/slUnZbCi/" rel="link-locale"/><link data-locale="sv_SE" href="https://se.tradingview.com/chart/slUnZbCi/" rel="link-locale"/><link data-locale="tr" href="https://tr.tradingview.com/chart/slUnZbCi/" rel="link-locale"/><link data-locale="ru" href="https://ru.tradingview.com/chart/slUnZbCi/" rel="link-locale"/><link data-locale="br" href="https://br.tradingview.com/chart/slUnZbCi/" rel="link-locale"/><link data-locale="id" href="https://id.tradingview.com/chart/slUnZbCi/" rel="link-locale"/><link data-locale="ms_MY" href="https://my.tradingview.com/chart/slUnZbCi/" rel="link-locale"/><link data-locale="th_TH" href="https://th.tradingview.com/chart/slUnZbCi/" rel="link-locale"/><link data-locale="vi_VN" href="https://vn.tradingview.com/chart/slUnZbCi/" rel="link-locale"/><link data-locale="ja" href="https://jp.tradingview.com/chart/slUnZbCi/" rel="link-locale"/><link data-locale="kr" href="https://kr.tradingview.com/chart/slUnZbCi/" rel="link-locale"/><link data-locale="zh_CN" href="https://cn.tradingview.com/chart/slUnZbCi/" rel="link-locale"/><link data-locale="zh_TW" href="https://tw.tradingview.com/chart/slUnZbCi/" rel="link-locale"/><link data-locale="ar_AE" href="https://ar.tradingview.com/chart/slUnZbCi/" rel="link-locale"/><link data-locale="he_IL" href="https://il.tradingview.com/chart/slUnZbCi/" rel="link-locale"/>
# <link href="https://s3.amazonaws.com" rel="dns-prefetch"/>
# <meta content="noindex, nofollow" name="robots"/>
# <meta content="f729ff74def35be4b9b92072c0e995b40fcb9e1aece03fb174343a1b7a5350ce" name="ahrefs-site-verification"/>
# <script type="application/ld+json">
# 	{
# 		"@context": "http://schema.org",
# 		"@type": "Organization",
# 		"url": "https://www.tradingview.com",
# 		"logo": "https://www.tradingview.com/static/images/logo-151x151.png",
# 		"name" : "TradingView",
# 		"sameAs" : ["https://www.facebook.com/tradingview/",
# 					"https://twitter.com/tradingview/",
# 					"https://www.youtube.com/channel/UCfOflihrkOKDQZ_ZKtF2VfQ/",
# 					"https://www.linkedin.com/company/tradingview/"]
# 	}
# </script>
# <link href="/static/images/favicon.ico" rel="icon"/>
# <meta content="TradingView" name="application-name"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="/static/images/favicon/manifest.json" rel="manifest"/>
# <meta content="#F8F9FD" media="(prefers-color-scheme: light)" name="theme-color"/> <meta content="#1E222D" media="(prefers-color-scheme: dark)" name="theme-color"/>
# <meta content="TradingView Site" name="apple-mobile-web-app-title"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
# <link href="/static/images/favicon/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
# <script nonce="">
# 	window.locale = 'en';
# 	window.language = 'en';
# </script>
# <script charset="utf-8" crossorigin="anonymous" defer="" src="/static/localization/translations/en.e7f3da1f7650b7a5.js"></script>
# <script crossorigin="anonymous" defer="" src="/static/bundles/runtime.b3352b263d7b3225a238.js" type="text/javascript"></script>
# <script crossorigin="anonymous" defer="" src="/static/bundles/vendors.9aa97809264f7e5ad100.js" type="text/javascript"></script>
# <script crossorigin="anonymous" defer="" src="/static/bundles/chart_not_found.9829382b6374c65fed18.js" type="text/javascript"></script>
# <link href="/static/bundles/base.539961cd41238fcb71c8.css" rel="stylesheet" type="text/css"/>
# <link href="/static/bundles/http_error_404_page.ea6e607a1456ea80ad62.css" rel="stylesheet" type="text/css"/>
# <script nonce="">
# 		window.initData = window.initData || {};
# 			!function(){"use strict";var e,t;!function(e){e.ThemeClassPrefix="theme-"}(e||(e={})),function(e){e.Light="light",e.Dark="dark"}(t||(t={}));const i="tradingview.current_theme.name";let o=window.localStorage.getItem(i);if(!o){const e=window.matchMedia&&window.matchMedia("(prefers-color-scheme: dark)").matches?t.Dark:t.Light;window.localStorage.setItem(i,e),o=e}!function(t,i=window){const o=e.ThemeClassPrefix+t,a=i.document.documentElement.classList;for(const t of Array.from(a))t.startsWith(e.ThemeClassPrefix)&&t!==o&&a.remove(t);a.add(o)}(o),window.initData.theme=o}();
# 	</script>
# <script nonce="">
# 		var is_authenticated = false;
# 		var user = {"username":"Guest","following":"0","followers":"0","ignore_list":[],"available_offers":{}};
# 		window.initData.api_host = 'payflowlink.paypal.com';
# 		window.initData.price_alerts_url = '//alerts.tradingview.com/alerts/';
# 		window.initData.screener_alerts_base_url = '//scanner-alerts.tradingview.com/screener_alerts/';
# 		window.initData.currentLocaleInfo = {"language":"en","language_name":"English","flag":"us","geoip_code":"us","priority":1000,"is_site_locale":true,"iso":"en","iso_639_3":"eng","show_on_widgets":true,"name_on_widgets":"English","global_name":"English","is_only_recommended_tw_autorepost":true};
# 		window.initData.offerButtonInfo = {};
# 		window.initData.settings = {'S3_LOGO_SERVICE_BASE_URL': 'https://s3-symbol-logo.tradingview.com/', 'WEBPACK_STATIC_PATH': '/static/bundles/'};
#
#
# 			window.__initialEnabledFeaturesets =
# 				(window.__initialEnabledFeaturesets || []).concat(
# 					['tv_production'].concat(
# 						window.ClientCustomConfiguration && window.ClientCustomConfiguration.getEnabledFeatureSet
# 							? JSON.parse(window.ClientCustomConfiguration.getEnabledFeatureSet())
# 							: []
# 					)
# 				);
#
# 			if (window.ClientCustomConfiguration && window.ClientCustomConfiguration.getDisabledFeatureSet) {
# 				window.__initialDisabledFeaturesets = JSON.parse(window.ClientCustomConfiguration.getDisabledFeatureSet());
# 			}
#
# 		window.WEBPACK_PUBLIC_PATH = '/static/bundles/';
#
# 			var lastGlobalNotificationIds = [8141,8122,8089,8086,8083,8079,8048,8027,7986,7955,7911];
#
# 		var shopConf = {
# 			offers: [],
# 		};
#
# 		var featureToggleState = {"hide_top_authors_at_feed_ideas":1.0,"people_page_disabled":1.0,"top_badges_disabled":1.0,"show_live_streams_on_main_page":1.0,"il_locale_enabled":1.0,"chart_autosave_5min":1.0,"chart_autosave_7min":1.0,"chart_autosave_10min":1.0,"remove_line_tools_from_content":1.0,"chart_storage_with_broker_name":1.0,"migrate_unloaded_charts":1.0,"subscribe_line_tool_notifications":0.5,"custom_tooltip_in_watch_list":1.0,"use_solid_line_style_for_traded_sources":1.0,"show_reverse_on_active_source_only":1.0,"alerts-send-extra-update":1.0,"hide_true_sms_alerts":1.0,"hide_alert_counter":1.0,"disable_idea_spam_filter":1.0,"timeout_django_db":0.15,"timeout_django_charts_db":0.25,"timeout_django_symbols_lists_db":0.25,"disable_services_monitor_metrics":1.0,"enable_signin_recaptcha":1.0,"enable_idea_spamdetectorml":1.0,"enable_idea_spamdetectorml_comments":1.0,"enable_idea_spam_checks_06_2021":1.0,"enable_inactive_users_cleanup":1.0,"evercookie_cancel_subscription":1.0,"financials_button":1.0,"google-ads":1.0,"google-one-tap-signin":1.0,"braintree-trial-implementation":1.0,"braintree-trial-in-order-dialog":1.0,"braintree-gopro-in-order-dialog":1.0,"braintree-apple-pay":1.0,"braintree-google-pay":1.0,"braintree-apple-pay-trial":1.0,"braintree-one-usd-verification":1.0,"lower_legend_collapser":1.0,"marked_symbols_enabled":1.0,"marketing-analytics":1.0,"marketing_email_checkbox":1.0,"marketing_features_gopro_cta":1.0,"news_separate_tab_enabled":1.0,"platform-ads-rotation":1.0,"rude_ideas":1.0,"save_all_charts_in_layout":1.0,"ses_tracking":1.0,"show_offline_bar":1.0,"show_portfolio_button":1.0,"sphinx_top_by_categories_enabled":1.0,"streams_enabled":1.0,"streams_live_notifications":1.0,"tvcoins_donations":1.0,"tvcoins_comment_donations":1.0,"twilio_messaging_service":1.0,"unsubscribe_inactive_users":1.0,"vat_disabled":1.0,"daily_donations_limit":1.0,"enable_non_unique_watch_sections":1.0,"enable_cyan_pink_watches":1.0,"enable_custom_lists_cross_tab_sync":1.0,"combine_add_and_move_symbols":1.0,"fail_on_duplicate_payment_methods_for_trial":1.0,"remove_wrap_text_legend":1.0,"disable_publish_strategy_range_based_chart":1.0,"hide_gopro_popup_upgrade_button":1.0,"show_strategy_margin_inputs":1.0,"snapshot_html_page":1.0,"screener_snowplow_enabled":1.0,"show_several_exchanges_for_stocks":1.0,"show_global_search_dialog":1.0,"streams_stats_profile":1.0,"restrict_simultaneous_requests":1.0,"popular_search_queries":1.0,"aggregating_page_pings":1.0,"remove_event_counters":1.0,"percentage_values_for_percentage_scale":1.0,"hide_historical_price_label":0.3,"hide_ranges_label_colors":0.3,"broker_ALOR":1.0,"broker_ALPACA":1.0,"broker_AMP":1.0,"broker_BINGBON":1.0,"broker_CAPITALCOM":1.0,"broker_CHAKA":1.0,"broker_CQG":1.0,"broker_CURRENCYCOM":1.0,"broker_FOREXCOM":1.0,"broker_FXCM":1.0,"broker_FXCM_token_v2":1.0,"broker_GEMINI":1.0,"broker_GLOBALPRIME":1.0,"broker_HITBTC":1.0,"broker_IBROKER":1.0,"broker_IRONBEAM":1.0,"broker_OANDA":1.0,"broker_SAXOBANK":1.0,"broker_TICKMILL":1.0,"broker_TIGER":1.0,"broker_TIMEX":1.0,"broker_TRADESTATION_V3":1.0,"broker_TRADOVATE":1.0,"broker_WHSELFINVEST":1.0,"broker_id_session":1.0,"new-broker-verifier":1.0,"mobile_trading_web":1.0,"mobile_trading_ios":1.0,"mobile_trading_android":1.0,"hide_real_brokers_on_mobile":1.0,"modal_suspend":1.0,"review_popup_on_chart":1.0};
# 	</script>
# <script nonce="">
# 	window.initData = window.initData || {};
#
# 	window.initData.snowplowSettings = {
# 		collectorId: 'tv_cf',
# 		url: 'snowplow-pixel.tradingview.com',
# 		params: {
# 			appId: 'tradingview',
# 		},
# 		enabled: true,
# 	}
# </script>
# <script nonce="">
# 		window.PUSHSTREAM_URL = 'wss://pushstream.tradingview.com';
# 		window.TV_LIVE_MEDIA_SERVER_LIVE_URLS = {"NA":"tv-live-dstream-us.tradingview.com","EU":"tv-live-dstream-eu.tradingview.com"};
# 		window.TV_LIVE_MEDIA_SERVER_DOMAIN = 'tv-dstream.tradingview.com';
# 		window.TV_LIVE_DIRECTOR_DOMAIN = 'tv-dlive.tradingview.com';
# 		window.TV_LIVE_MEDIA_URL = 'https://tv-recorder-storage-us.tradingview.com';
# 		window.CHARTEVENTS_URL = 'https://chartevents-reuters.tradingview.com/';
# 		window.EARNINGS_CALENDAR_URL = '//scanner.tradingview.com';
# 		window.NEWS_SERVICE_URL = 'https://news-headlines.tradingview.com';
# 		window.SS_HOST = 'symbol-search.tradingview.com';
# 		window.SS_URL = '';
# 		window.SS_DOMAIN_PARAMETER = 'production';
# 		window.DEFAULT_SYMBOL = 'NASDAQ:AAPL';
# 		window.COUNTRY_CODE_TO_DEFAULT_EXCHANGE = {"en":"US","us":"NASDAQ","ae":"DFM","ar":"BCBA","au":"ASX","be":"EURONEXTBRU","bh":"BAHRAIN","br":"BMFBOVESPA","ca":"TSX","ch":"SIX","cl":"BCS","zh_CN":"SSE","co":"BVC","de_DE":"FWB","dk":"OMXCOP","ee":"OMXTSE","eg":"EGX","es":"BME","fi":"OMXHEX","fr":"EURONEXT_PAR","hk":"HKEX","id":"IDX","il":"TASE","in":"BSE","is":"OMXICE","it":"MIL","ja":"TSE","kr":"KRX","lt":"OMXVSE","lv":"OMXRSE","lu":"LUXSE","mx":"BMV","ms_MY":"MYX","ng":"NSENG","nl":"EURONEXT_AMS","no":"OSL","nz":"NZX","pe":"BVL","pl":"GPW","pt":"EURONEXT_LIS","qa":"QSE","rs":"BELEX","ru":"MOEX","ar_AE":"TADAWUL","sv_SE":"NGM","sg":"SGX","th_TH":"SET","tr":"BIST","zh_TW":"TWSE","uk":"LSE","vi_VN":"HOSE","za":"JSE"};
# 		window.HOTLISTS_URL = 'https://hotlist.tradingview.com/';
# 		window.SCREENER_HOST = 'https://scanner.tradingview.com';
# 		window.AWS_BBS3_DOMAIN = 'https://tradingview-user-uploads.s3.amazonaws.com';
#
# 			window.DATA_ISSUES_HOST = 'https://support-middleware.tradingview.com';
#
# 		window.TELEMETRY_HOSTS = {"charts":{"free":"//telemetry.tradingview.com/free","pro":"//telemetry.tradingview.com/pro","widget":"//telemetry.tradingview.com/widget","ios_free":"//telemetry.tradingview.com/charts-ios-free","ios_pro":"//telemetry.tradingview.com/charts-ios-pro","android_free":"//telemetry.tradingview.com/charts-android-free","android_pro":"//telemetry.tradingview.com/charts-android-pro"},"alerts":{"all":"//telemetry.tradingview.com/alerts"},"news":{"all":"//telemetry.tradingview.com/news"},"pine":{"all":"//telemetry.tradingview.com/pine"},"calendars":{"all":"//telemetry.tradingview.com/calendars"},"site":{"free":"//telemetry.tradingview.com/site-free","pro":"//telemetry.tradingview.com/site-pro","widget":"//telemetry.tradingview.com/site-widget"},"trading":{"all":"https://telemetry.tradingview.com/trading"}};
# 		window.TELEMETRY_WS_ERROR_LOGS_THRESHOLD = '100';
# 		window.RECAPTCHA_SITE_KEY = '6Lcqv24UAAAAAIvkElDvwPxD0R8scDnMpizaBcHQ';
# 		window.RECAPTCHA_SITE_KEY_V3 = '6LeQMHgUAAAAAKCYctiBGWYrXN_tvrODSZ7i9dLA';
# 		window.GOOGLE_CLIENT_ID = '236720109952-v7ud8uaov0nb49fk5qm03as8o7dmsb30.apps.googleusercontent.com';
#
# 		window.PINE_URL = '//pine-facade.tradingview.com/pine-facade';
# 	</script>
# <script charset="utf-8" src="/static/bundles/conversion.b820053856a55bc984a2.js"></script><script charset="utf-8" src="/static/bundles/gdpr-notification.aa39ed67ab071b1c82e0.js"></script><script charset="utf-8" src="/static/bundles/187.5c1598b58180f1ff211b.js"></script><script charset="utf-8" src="/static/bundles/open-support-dialog-on-load.98707a4956608ed63fff.js"></script><script charset="utf-8" src="/static/bundles/open-payment-order-dialog-on-load.ce581f3d64d5c1777134.js"></script><script charset="utf-8" src="/static/bundles/open-coins-dialog-on-load.2cbcfbb199ed62ce45ca.js"></script><link href="/static/bundles/2.ec35a19db935279c5b42.css" rel="stylesheet" type="text/css"/><link href="/static/bundles/16.acbd65fff0ff2e115f40.css" rel="stylesheet" type="text/css"/><link href="/static/bundles/23.cf9820a9983bac342091.css" rel="stylesheet" type="text/css"/><link href="/static/bundles/25.03d0954b1559e4dc5acf.css" rel="stylesheet" type="text/css"/><link href="/static/bundles/29.52de8746fd790e744c23.css" rel="stylesheet" type="text/css"/><link href="/static/bundles/33.4b40de43aeb228712da8.css" rel="stylesheet" type="text/css"/><link href="/static/bundles/37.d95112ce98c9ab22a2d2.css" rel="stylesheet" type="text/css"/><link href="/static/bundles/40.f11c933501520faf0345.css" rel="stylesheet" type="text/css"/><link href="/static/bundles/43.ea4b8f4cdcac6ee02d81.css" rel="stylesheet" type="text/css"/><link href="/static/bundles/54.85d85d0d4bbe67413fa8.css" rel="stylesheet" type="text/css"/><link href="/static/bundles/59.c41601196c1ec46baa99.css" rel="stylesheet" type="text/css"/><link href="/static/bundles/65.1f33026fd12bb2fb7ea8.css" rel="stylesheet" type="text/css"/><link href="/static/bundles/92.3b5ecdf3865628c87cfd.css" rel="stylesheet" type="text/css"/><link href="/static/bundles/96.f71a6811d0ae7504a57b.css" rel="stylesheet" type="text/css"/><link href="/static/bundles/114.87e2856b102e4bce5ee9.css" rel="stylesheet" type="text/css"/><link href="/static/bundles/128.e0f823115e04cca17461.css" rel="stylesheet" type="text/css"/><link href="/static/bundles/131.df4b6c353dbb81797d47.css" rel="stylesheet" type="text/css"/><link href="/static/bundles/134.f3c61a0cd1a1f44c0511.css" rel="stylesheet" type="text/css"/><link href="/static/bundles/156.1374ec4c633e413b2800.css" rel="stylesheet" type="text/css"/><link href="/static/bundles/157.e4e5df6ca4b68486e522.css" rel="stylesheet" type="text/css"/><link href="/static/bundles/167.cb4cbc28bf4306da8162.css" rel="stylesheet" type="text/css"/><link href="/static/bundles/397.c5f180d371b4b454c8cd.css" rel="stylesheet" type="text/css"/><link href="/static/bundles/583.52c7d9888f97396ffcc2.css" rel="stylesheet" type="text/css"/><script charset="utf-8" src="/static/bundles/17.263b798363f9786245e9.js"></script><script charset="utf-8" src="/static/bundles/28.147d8ab3ac0ebf0a2bf8.js"></script><script charset="utf-8" src="/static/bundles/82.68693676af0204d1002c.js"></script><script charset="utf-8" src="/static/bundles/81.05780ae8530d22be9cf1.js"></script><script charset="utf-8" src="/static/bundles/110.099d413cfdf13432f538.js"></script><script charset="utf-8" src="/static/bundles/125.da3f9784912075b894a0.js"></script><script charset="utf-8" src="/static/bundles/144.5749bd6f988d1bc342bd.js"></script><script charset="utf-8" src="/static/bundles/150.1a062b9d613599439a3e.js"></script><script charset="utf-8" src="/static/bundles/159.367f19788aba39a7b019.js"></script><script charset="utf-8" src="/static/bundles/209.1bf9a83fb42069e72a58.js"></script><script charset="utf-8" src="/static/bundles/tv-user-link-popup.82c3e019e251d1080723.js"></script><script async="" nonce="" src="https://accounts.google.com/gsi/client"></script><script charset="utf-8" src="/static/bundles/75.ef893b7a13b5cecc19c8.js"></script><script charset="utf-8" src="/static/bundles/89.f9ae26b165d0fa6a93f5.js"></script><script charset="utf-8" src="/static/bundles/127.a097ac0c5ad5d839bc0e.js"></script><script charset="utf-8" src="/static/bundles/141.0239 ...
# /*# sourceURL=/_/gsi/_/ss/k=gsi.gsi.5AD4Gd3Cvak.L.W.O/am=chE/d=1/rs=AF0KOtVbishvpMTsNg7mVrEgSmM_mVtw0g/m=gis_client_button_style */</style></head>
# <body class="">
# <script nonce="">
# (function(){
# 	var frame = null;
# 	var fn = function() {
# 		var widgetBarTabsWidth = 46;
# 		var offsetWidth = document.body.offsetWidth;
# 		var widgetBarWidth = parseFloat(document.body.style.paddingRight || 0);
# 		var offsetWidthPadded = offsetWidth - widgetBarWidth; 		document.body.classList[offsetWidth > 1576 ? 'add' : 'remove']('popup-wide');
# 		document.body.classList[offsetWidthPadded > 1530 ? 'add' : 'remove']('page-wide');
# 		document.body.classList.toggle('is-widgetbar-expanded', widgetBarWidth > widgetBarTabsWidth);
# 		frame = null;
# 	}
# 	var fnRaf = function() {
# 		if (frame === null) {
# 			frame = window.requestAnimationFrame(fn);
# 		}
# 	};
# 	fn();
# 	window.addEventListener('resize', fnRaf, false);
# })();
# </script>
# <div class="widgetbar-place"></div>
# <div class="tv-main">
# <div class="js-container-android-notification"></div>
# <div class="js-container-ios-notification"></div>
# <div class="tv-header tv-header__top js-site-header-container tv-header--sticky">
# <div class="tv-header__backdrop"></div>
# <div class="tv-header__inner">
# <div class="tv-header__area tv-header__area--logo-menu">
# <button class="tv-header__hamburger-menu js-header-main-menu-mobile-button">
# <svg height="12" viewbox="0 0 18 12" width="18" xmlns="http://www.w3.org/2000/svg"><path d="M0 12h18v-2h-18v2zm0-5h18v-2h-18v2zm0-7v2h18v-2h-18z" fill="currentColor"></path></svg>
# </button>
# <span class="tv-header__logo">
# <a aria-label="TradingView main page" class="tv-header__link tv-header__link--logo" href="/">
# <span class="tv-header__icon">
# <svg height="28" viewbox="0 0 36 28" width="36" xmlns="http://www.w3.org/2000/svg"><path d="M14 22H7V11H0V4h14v18zM28 22h-8l7.5-18h8L28 22z" fill="currentColor"></path><circle cx="20" cy="8" fill="currentColor" r="4"></circle></svg>
# </span>
# <span class="tv-header__icon tv-header__logo-text">
# <svg height="28" viewbox="0 0 147 28" width="147" xmlns="http://www.w3.org/2000/svg"><path d="M4.793 22.024h3.702V7.519h4.843V4.02H0v3.5h4.793v14.504zM13.343 22.024h3.474v-6.06c0-2.105 1.09-3.373 2.74-3.373.582 0 1.039.101 1.571.279V9.345a3.886 3.886 0 00-1.166-.152c-1.42 0-2.713.938-3.145 2.18V9.346h-3.474v12.679zM27.796 22.303c1.75 0 3.068-.888 3.652-1.7v1.42h3.474V9.346h-3.474v1.42c-.584-.811-1.902-1.699-3.652-1.699-3.372 0-5.959 3.043-5.959 6.618 0 3.576 2.587 6.619 5.96 6.619zm.736-3.17c-1.928 0-3.196-1.445-3.196-3.448 0-2.004 1.268-3.45 3.196-3.45 1.927 0 3.195 1.446 3.195 3.45 0 2.003-1.268 3.448-3.195 3.448zM43.193 22.303c1.75 0 3.068-.888 3.651-1.7v1.42h3.474V3.007h-3.474v7.76c-.583-.812-1.901-1.7-3.651-1.7-3.373 0-5.96 3.043-5.96 6.618 0 3.576 2.587 6.619 5.96 6.619zm.735-3.17c-1.927 0-3.195-1.445-3.195-3.448 0-2.004 1.268-3.45 3.195-3.45 1.927 0 3.195 1.446 3.195 3.45 0 2.003-1.268 3.448-3.195 3.448zM55.166 7.412a2.213 2.213 0 002.232-2.206A2.213 2.213 0 0055.166 3a2.224 2.224 0 00-2.206 2.206 2.224 2.224 0 002.206 2.206zm-1.724 14.612h3.474V9.49h-3.474v12.533zM59.998 22.024h3.474v-6.187c0-2.435 1.192-3.601 2.815-3.601 1.445 0 2.232 1.116 2.232 2.941v6.847h3.474v-7.43c0-3.296-1.826-5.528-4.894-5.528-1.649 0-2.942.71-3.627 1.724V9.345h-3.474v12.679zM80.833 18.65c-1.75 0-3.22-1.319-3.22-3.246 0-1.952 1.47-3.246 3.22-3.246 1.75 0 3.22 1.294 3.22 3.246 0 1.927-1.47 3.246-3.22 3.246zm-.406 8.85c3.88 0 6.822-1.978 6.822-6.543V9.268h-3.474v1.42C83.09 9.7 81.72 8.99 80.098 8.99c-3.322 0-5.985 2.84-5.985 6.415 0 3.55 2.663 6.39 5.985 6.39 1.623 0 2.992-.735 3.677-1.673v.862c0 2.029-1.344 3.474-3.398 3.474-1.42 0-2.84-.482-3.956-1.572l-1.902 2.586c1.445 1.395 3.702 2.029 5.908 2.029zM94.594 22.024h3.27L105.32 4.02h-4.057l-5.021 12.501L91.145 4.02h-3.981l7.43 18.004zM108.508 7.266a2.213 2.213 0 002.231-2.206 2.213 2.213 0 00-2.231-2.206c-1.192 0-2.207.988-2.207 2.206 0 1.217 1.015 2.206 2.207 2.206zm-1.725 14.758h3.474V9.345h-3.474v12.679zM119.248 22.303c2.662 0 4.691-1.116 5.883-2.84l-2.587-1.927c-.583.887-1.673 1.597-3.271 1.597-1.673 0-3.169-.938-3.372-2.637h9.483c.076-.533.051-.888.051-1.192 0-4.133-2.916-6.238-6.238-6.238-3.854 0-6.669 2.865-6.669 6.618 0 4.007 2.942 6.619 6.72 6.619zm-3.221-8.165c.33-1.547 1.775-2.207 3.069-2.207 1.293 0 2.561.685 2.865 2.207h-5.934zM138.45 22.024h3.449l4.184-12.679h-3.728l-2.383 8.114-2.587-8.114h-2.662l-2.561 8.114-2.409-8.114h-3.703l4.21 12.679h3.448l2.359-7.202 2.383 7.202z" fill="currentColor"></path></svg>
# </span>
# </a>
# </span>
# </div>
# <div class="tv-header__middle-content">
# <div class="tv-header__area tv-header__area--search">
# <div class="tv-header-search-container">
# <button aria-label="Search" class="tv-header-search-container tv-header-search-container__button tv-header-search-container__button--full js-header-search-button">
# <svg fill="currentColor" height="28" viewbox="0 0 28 28" width="28" xmlns="http://www.w3.org/2000/svg"><path d="M18.162 17.089a7.412 7.412 0 10-1.06 1.062l4.774 4.679a.75.75 0 101.05-1.071l-4.764-4.67zm-5.75 1.235a5.912 5.912 0 110-11.824 5.912 5.912 0 010 11.823z"></path></svg>
# <span class="tv-header-search-container__text">Search</span>
# <span class="tv-header-search-container__hotkey js-search-hotkey-hint">⌘K</span>
# </button>
# <button aria-label="Search" class="tv-header-search-container__button tv-header-search-container__button--simple js-header-search-button"><svg fill="currentColor" height="28" viewbox="0 0 28 28" width="28" xmlns="http://www.w3.org/2000/svg"><path d="M18.162 17.089a7.412 7.412 0 10-1.06 1.062l4.774 4.679a.75.75 0 101.05-1.071l-4.764-4.67zm-5.75 1.235a5.912 5.912 0 110-11.824 5.912 5.912 0 010 11.823z"></path></svg></button>
# </div> </div>
# <div class="tv-header__area tv-header__area--menu js-header-main-menu">
# <div class="tv-mainmenu">
# <ul class="tv-mainmenu__list js-header-main-menu-list"><li class="tv-mainmenu__item tv-mainmenu__item--chart"> <a data-type="chart" href="/chart/"><svg height="28" viewbox="0 0 28 28" width="28" xmlns="http://www.w3.org/2000/svg"><path d="M8 5.5h12A2.5 2.5 0 0 1 22.5 8v12a2.5 2.5 0 0 1-2.5 2.5H8A2.5 2.5 0 0 1 5.5 20V8A2.5 2.5 0 0 1 8 5.5zM4 8a4 4 0 0 1 4-4h12a4 4 0 0 1 4 4v12a4 4 0 0 1-4 4H8a4 4 0 0 1-4-4V8zm15.49 5.07a.75.75 0 1 0-.98-1.14l-2.97 2.55-2.51-2.51a.75.75 0 0 0-1.02-.04l-3.5 3a.75.75 0 1 0 .98 1.14l2.97-2.55 2.51 2.51c.28.28.72.3 1.02.04l3.5-3z" fill="currentColor" fill-rule="evenodd"></path></svg>Chart</a></li><li class="tv-mainmenu__item"> <a data-type="brokers" href="/brokers/">Brokers</a></li><li class="tv-mainmenu__item"> <a data-type="markets" href="/markets/">Markets</a><ul class="i-hidden"><li> <a data-type="bitcoin" href="/markets/cryptocurrencies/">Cryptocurrencies</a><ul><li> <a data-hide-on-mobile="true" data-type="crypto-screener" href="/crypto-screener/">Crypto Screener</a></li><li> <a href="/markets/cryptocurrencies/prices-all/">Prices</a></li><li> <a href="/markets/cryptocurrencies/defi/">DeFi Coins</a></li><li> <a href="/markets/cryptocurrencies/global-charts/">Market Cap charts</a></li><li> <a href="/markets/cryptocurrencies/global-defi-charts/">DeFi Market Cap charts</a></li><li> <a href="/markets/cryptocurrencies/prices-bitcoin/">Bitcoin</a></li><li> <a href="/markets/cryptocurrencies/prices-xrp/">XRP</a></li><li> <a href="/markets/cryptocurrencies/prices-ethereum/">Ethereum</a></li><li> <a href="/markets/cryptocurrencies/prices-bitcoin-cash/">Bitcoin Cash</a></li><li> <a href="/markets/cryptocurrencies/prices-eos/">EOS</a></li><li> <a href="/markets/cryptocurrencies/prices-stellar/">Stellar</a></li><li> <a href="/markets/cryptocurrencies/prices-litecoin/">Litecoin</a></li><li> <a href="/markets/cryptocurrencies/prices-bitcoin-sv/">Bitcoin SV</a></li><li> <a href="/markets/cryptocurrencies/prices-tether/">Tether</a></li></ul><p data-watchlist=""><a data-symbol="CRYPTOCAP:TOTAL" href="/symbols/CRYPTOCAP-TOTAL/">Crypto Market Cap</a>, <a data-symbol="BITSTAMP:BTCUSD" href="/symbols/BTCUSD/">BTC/USD</a>, <a data-symbol="BITSTAMP:ETHUSD" href="/symbols/ETHUSD/">ETH/USD</a>, <a data-symbol="COINBASE:USDTUSD" href="/symbols/USDTUSD/">USDT/USD</a>, <a data-symbol="BITSTAMP:XRPUSD" href="/symbols/XRPUSD/">XRP/USD</a>, <a data-symbol="CME:BTC1!" href="/symbols/CME-BTC1!/">Bitcoin</a></p></li><li> <a data-type="forex" href="/markets/currencies/">Currencies</a><ul><li> <a data-hide-on-mobile="true" data-type="calendar" href="/markets/currencies/economic-calendar/">Economic Calendar</a></li><li> <a data-hide-on-mobile="true" data-type="forex-screener" href="/forex-screener/">Forex Screener</a></li><li> <a href="/markets/currencies/rates-major/">Major</a></li><li> <a href="/markets/currencies/rates-minor/">Minor</a></li><li> <a href="/markets/currencies/rates-exotic/">Exotic</a></li><li> <a href="/markets/currencies/rates-americas/">Americas</a></li><li> <a href="/markets/currencies/rates-europe/">Europe</a></li><li> <a href="/markets/currencies/rates-asia/">Asia</a></li><li> <a href="/markets/currencies/rates-pacific/">Pacific</a></li><li> <a href="/markets/currencies/rates-middle-east/">Middle East</a></li><li> <a href="/markets/currencies/rates-africa/">Africa</a></li><li> <a href="/markets/currencies/cross-rates-overview-prices/">Cross Rates</a></li><li> <a href="/markets/currencies/cross-rates-overview-heat-map/">Heat Map</a></li><li> <a href="/markets/currencies/indices-all/">Currency indices</a></li></ul><p data-watchlist=""><a data-symbol="FX_IDC:EURUSD" href="/symbols/EURUSD/">EUR/USD</a>, <a data-symbol="FX_IDC:GBPUSD" href="/symbols/GBPUSD/">GBP/USD</a>, <a data-symbol="FX_IDC:USDJPY" href="/symbols/USDJPY/">USD/JPY</a>, <a data-symbol="FX_IDC:AUDUSD" href="/symbols/AUDUSD/">AUD/USD</a>, <a data-symbol="FX_IDC:USDCAD" href="/symbols/USDCAD/">USD/CAD</a>, <a data-symbol="FX_IDC:USDCHF" href="/symb ...
# </div>
# <div class="tv-header__area tv-header__area--user">
# <button aria-haspopup="true" aria-label="Open user menu" class="tv-header__user-menu-button tv-header__user-menu-button--anonymous js-header-user-menu-button" type="button">
# <svg height="28" viewbox="0 0 28 28" width="28" xmlns="http://www.w3.org/2000/svg"><path d="M17.5 9c0 1.14-.3 1.99-.79 2.54-.46.52-1.27.96-2.71.96s-2.25-.44-2.71-.96A3.74 3.74 0 0 1 10.5 9c0-1.14.3-1.99.79-2.54.46-.52 1.27-.96 2.71-.96s2.25.44 2.71.96c.5.55.79 1.4.79 2.54zM19 9c0 2.76-1.45 5-5 5s-5-2.24-5-5 1.45-5 5-5 5 2.24 5 5zm-8 8.5h6c2.04 0 3.1.5 3.76 1.1.69.63 1.11 1.55 1.5 2.8.13.42.04.95-.29 1.4-.33.46-.8.7-1.22.7H7.25c-.43 0-.89-.24-1.22-.7a1.61 1.61 0 0 1-.3-1.4 6.08 6.08 0 0 1 1.51-2.8c.65-.6 1.72-1.1 3.76-1.1zm6-1.5h-6c-4.6 0-5.88 2.33-6.7 4.96-.58 1.89.97 4.04 2.95 4.04h13.5c1.98 0 3.53-2.15 2.95-4.04C22.88 18.33 21.6 16 17 16z" fill="currentColor" fill-rule="evenodd"></path></svg>
# </button>
# <button aria-haspopup="true" aria-label="Open user menu" class="tv-header__user-menu-button tv-header__user-menu-button--logged js-header-user-menu-button" type="button">
# <img alt="" aria-hidden="true" class="tv-header__user-menu-button-userpic js-userpic-mid"/>
# <i class="tv-header__icon--counter-red js-notifications-indicator i-hidden"></i>
# </button>
# <div class="js-offer-button"></div>
# </div>
# </div>
# </div>
# <div class="tv-content">
# <div class="tv-http-error-page__wrapper">
# <div class="tv-http-error-page js-chart-view">
# <div class="tv-http-error-page__image tv-http-error-page__image--invalid-link"></div>
# <h1 class="tv-http-error-page__title">
# 				We can't open this chart layout for you
# 			</h1><p class="tv-http-error-page__text tv-http-error-page__text-align-start">If you're the owner of this chart layout then you need to <a class="js-login-link" href="#signin">log in</a> to be able to see it.</p>
# <p class="tv-http-error-page__text tv-http-error-page__text-align-start">
# 				If you wish to see someone else's chart layout, then please ask the owner to enable chart layout sharing, or to publish it by clicking the Publish Idea button.
# 			</p> <a class="tv-button tv-button--primary tv-button--size_large tv-http-error-page__button" href="/">
# 			Head to homepage
# 		</a>
# </div>
# </div>
# </div>
# <hr class="tv-footer-separator"/>
# <footer class="tv-footer js-footer">
# <div class="tv-footer__row">
# <div class="tv-footer__logo-socials">
# <a aria-label="TradingView main page" class="tv-footer-logo" href="/">
# <svg height="60" width="169" xmlns="http://www.w3.org/2000/svg"><use href="/static/images/svg/tradingview-with-text-logo.svg#tradingview-logo"></use></svg>
# </a>
# <ul class="tv-footer-socials"><li class="tv-footer-socials__item">
# <a aria-label="TradingView on Twitter" class="tv-footer-socials__icon tv-footer-socials__icon--twitter" href="https://twitter.com/tradingview/" rel="nofollow" target="_blank">
# <svg height="28" width="28" xmlns="http://www.w3.org/2000/svg"><use href="/static/bundles/ui-lib/icons/28px-filled/social-icons/twitter-color-off.svg#twitter"></use></svg>
# </a>
# </li><li class="tv-footer-socials__item">
# <a aria-label="TradingView on Facebook" class="tv-footer-socials__icon tv-footer-socials__icon--facebook" href="https://www.facebook.com/tradingview/" rel="nofollow" target="_blank">
# <svg height="28" width="28" xmlns="http://www.w3.org/2000/svg"><use href="/static/bundles/ui-lib/icons/28px-filled/social-icons/facebook-color-off.svg#facebook"></use></svg>
# </a>
# </li><li class="tv-footer-socials__item">
# <a aria-label="TradingView on YouTube" class="tv-footer-socials__icon tv-footer-socials__icon--youtube" href="https://www.youtube.com/channel/UCfOflihrkOKDQZ_ZKtF2VfQ/" rel="nofollow" target="_blank">
# <svg height="28" width="28" xmlns="http://www.w3.org/2000/svg"><use href="/static/bundles/ui-lib/icons/28px-filled/social-icons/youtube-color-off.svg#youtube"></use></svg>
# </a>
# </li><li class="tv-footer-socials__item">
# <a aria-label="TradingView on Instagram" class="tv-footer-socials__icon tv-footer-socials__icon--instagram" href="https://www.instagram.com/tradingview/" rel="nofollow" target="_blank">
# <svg height="28" width="28" xmlns="http://www.w3.org/2000/svg"><use href="/static/bundles/ui-lib/icons/28px-filled/social-icons/instagram-color-off.svg#instagram"></use></svg>
# </a>
# </li><li class="tv-footer-socials__item">
# <a aria-label="TradingView on Telegram" class="tv-footer-socials__icon tv-footer-socials__icon--telegram" href="https://t.me/tradingview/" rel="nofollow" target="_blank">
# <svg height="28" width="28" xmlns="http://www.w3.org/2000/svg"><use href="/static/bundles/ui-lib/icons/28px-filled/social-icons/telegram-color-off.svg#telegram"></use></svg>
# </a>
# </li><li class="tv-footer-socials__item">
# <a aria-label="TradingView on TikTok" class="tv-footer-socials__icon tv-footer-socials__icon--tiktok" href="https://www.tiktok.com/@tradingview/" rel="nofollow" target="_blank">
# <svg height="28" width="28" xmlns="http://www.w3.org/2000/svg"><use href="/static/bundles/ui-lib/icons/28px-filled/social-icons/tiktok-color-off.svg#tiktok"></use></svg>
# </a>
# </li><li class="tv-footer-socials__item">
# <a aria-label="TradingView on Reddit" class="tv-footer-socials__icon tv-footer-socials__icon--reddit" href="https://www.reddit.com/r/TradingView/" rel="nofollow" target="_blank">
# <svg height="28" width="28" xmlns="http://www.w3.org/2000/svg"><use href="/static/bundles/ui-lib/icons/28px-filled/social-icons/reddit-color-off.svg#reddit"></use></svg>
# </a>
# </li><li class="tv-footer-socials__item">
# <a aria-label="TradingView on Discord" class="tv-footer-socials__icon tv-footer-socials__icon--discord" href="https://discord.gg/wzxSbFMJuV" rel="nofollow" target="_blank">
# <svg height="28" width="28" xmlns="http://www.w3.org/2000/svg"><use href="/static/bundles/ui-lib/icons/28px-filled/social-icons/discord-color-off.svg#discord"></use></svg>
# </a>
# </li><li class="tv-footer-socials__item">
# <a aria-label="TradingView on LinkedIn" class="tv-footer-socials__icon tv-footer-socials__icon--linkedin" href="https://www.linkedin.com/company/tradingview/" rel="nofollow" target="_blank">
# <svg height="28" width="28" xmlns="http://www.w3.org/2000/svg"><use href="/static/bundles/ui-lib/icons/28px-filled/social-icons/linkedin-color-off.svg#linkedin"></use></svg>
# </a>
# </li></ul></div>
# <div class="tv-footer-links">
# <div class="tv-footer-links__row-group">
# <div class="tv-footer-links-column">
# <span class="tv-footer-links-column__title">Products</span>
# <ul class="tv-footer-links-column__list">
# <li>
# <a class="tv-footer-links-column__link" href="/chart/">Chart</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="https://www.tradingview.com/pine-script-docs/en/v4/Introduction.html" target="_blank">Pine Script</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="/screener/">Stock Screener</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="/forex-screener/">Forex Screener</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="/crypto-screener/">Crypto Screener</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="/heatmap/stock/">Stock Heatmap</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="/heatmap/crypto/">Crypto Heatmap</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="/markets/currencies/economic-calendar/">Economic Calendar</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="/markets/stocks-usa/earnings/">Earnings Calendar</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link js-footer-trading-view-desktop-link" href="/desktop/">TradingView Desktop</a>
# </li>
# </ul>
# </div>
# <div class="tv-footer-links-column">
# <span class="tv-footer-links-column__title">Company</span>
# <ul class="tv-footer-links-column__list">
# <li>
# <a class="tv-footer-links-column__link" href="/about/">About</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="/features/">Features</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="/gopro/?source=footer&amp;feature=pricing">Pricing</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="/wall-of-love/">Wall of Love</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="https://www.tradingview.com/blog/en/" target="_blank">Blog</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="/bounty/">Security vulnerability</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="https://status.tradingview.com/" target="_blank">Status page</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="/policies/">Terms of use</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="/disclaimer/">Disclaimer</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="/privacy-policy/">Privacy policy</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="/cookies-policy/">Cookies policy</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="tv-footer-links__row-group">
# <div class="tv-footer-links-column">
# <span class="tv-footer-links-column__title">Community</span>
# <ul class="tv-footer-links-column__list">
# <li>
# <a class="tv-footer-links-column__link" href="/share-your-love/?source=footer&amp;feature=refer_friend">Refer a friend</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="/ideas/">Ideas</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="/scripts/">Scripts</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="/streams/">Streams</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="/house-rules/">House rules</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="/moderators/">Moderators</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="/pine-wizards/">Pine Wizards</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="/chat/" target="_blank">Chat</a>
# </li>
# </ul>
# </div>
# <div class="tv-footer-links-column">
# <span class="tv-footer-links-column__title">For business</span>
# <ul class="tv-footer-links-column__list">
# <li>
# <a class="tv-footer-links-column__link" href="/widget/">Widgets</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="/advertising-info/">Advertising</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="/tradingview-for-the-web/">Website &amp; broker solutions</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="/HTML5-stock-forex-bitcoin-charting-library/">Charting solutions</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="/lightweight-charts/">Lightweight Charting Library</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="/brokerage-integration/">Brokerage integration</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="/referral-program/">Partner program</a>
# </li>
# <li>
# <a class="tv-footer-links-column__link" href="/publishing-tools/">Content streams &amp; RSS</a>
# </li>
# </ul>
# </div>
# </div>
# </div></div>
# <div class="tv-footer__markets-copyright">
# <div class="tv-footer-markets">
# <div class="tv-footer-markets__row-group">
# <a class="tv-footer-markets__link js-footer-markets-link" data-platform="ios" href="https://itunes.apple.com/us/app/tradingview-trading-community-charts-and-quotes/id1205990992?pt=118302550&amp;ct=footer" rel="nofollow" target="_blank">
# <img alt="Download on the App Store" class="tv-footer-markets__icon" loading="lazy" src="/static/images/svg/app-store-badge/light-theme/app-store-badge-en.svg"/>
# <img alt="Download on the App Store" class="tv-footer-markets__icon--dark" loading="lazy" src="/static/images/svg/app-store-badge/dark-theme/app-store-badge-en.svg"/>
# </a>
# <a class="tv-footer-markets__link js-footer-markets-link" data-platform="android" href="https://play.google.com/store/apps/details?id=com.tradingview.tradingviewapp&amp;referrer=utm_source%3Dtradingview%26utm_medium%3Dgplay_footer" rel="nofollow" target="_blank">
# <img alt="Get it on Google Play" class="tv-footer-markets__icon" loading="lazy" src="/static/images/svg/google-play-badge/light-theme/google-play-badge-en.svg"/>
# <img alt="Get it on Google Play" class="tv-footer-markets__icon--dark" loading="lazy" src="/static/images/svg/google-play-badge/dark-theme/google-play-badge-en.svg"/>
# </a>
# </div>
# <div class="tv-footer-markets__row-group">
# <a class="tv-footer-markets__link js-footer-markets-link" data-platform="desktop" href="/desktop/">
# <img alt="Download Desktop app" class="tv-footer-markets__icon" loading="lazy" src="/static/images/svg/app-desktop-badge/light-theme/app-desktop-badge-en.svg"/>
# <img alt="Download Desktop app" class="tv-footer-markets__icon--dark" loading="lazy" src="/static/images/svg/app-desktop-badge/dark-theme/app-desktop-badge-en.svg"/>
# </a>
# </div>
# </div>
# <div class="tv-footer-copyright">
# <span>
# 		Select market data provided <span class="i-no-break">by		<a class="tv-footer-copyright__link" href="https://www.theice.com/market-data" rel="nofollow" target="_blank">ICE Data Services</a>
# </span> </span>
# <span class="tv-footer-copyright__date">© 2021 TradingView</span>
# </div></div>
# </footer> </div>
# <script nonce="">window.fbAppId = 155037361239837;</script>
# <script nonce="">
# 		window.BLOG_LOCALIZED_URL = 'https://www.tradingview.com/blog/en/';
#
#
# 		initData.idc_exchanges_list = ["dfm","nzx","nzx_futures","bme","luxse","szse","hkex","hkex_futures","nag","tse","tfx","tocom","ose","sgx","sgx_stocks","sgx_futures","twse","bcba","bovespa_stocks","bovespa_futures","bvc","bmv","bvl","bcs","six","bahrain","belex","egx","nseng","idx","qse"]
# 		initData.idc_delay_exchanges_list = ["nzx_futures","luxse","tfx","bvc","bahrain","belex"]
# 		initData.block_widgetbar = function (WidgetBar, ContentPageResizer, RootResizer, configuration) {
# 					loginStateChange.subscribe(this, function (is_initial) {
# 						if(!is_initial && !window.widgetbar && user && is_authenticated){
# 							var resizer = new ContentPageResizer(window);
# 							window.widgetbar = new WidgetBar({
# 								resizerBridge: resizer.allocate({ areaName: 'right' }),
# 								adaptive: true,
# 								settingsPrefix: 'widgetbar',
# 								instantLoad: true,
# 								configuration: configuration,
# 							});
# 						}
# 					})
# 		};
#
# 			initData.offlineAlertEventsOnInit = true;
#
# 			initData.block_symbol_autolink = function () {
# 				TradingView.Linking.symbol.setValue(TVSettings.getValue('editchart.model.symbol', DEFAULT_SYMBOL));
# 			};
#
# 	</script>
# <meta content="prod-frontend-web-b-1" name="tv:server-name"/>
# <div id="tooltip-root-element"></div><div data-callback="handleGoogleCredentialResponse" data-client_id="236720109952-v7ud8uaov0nb49fk5qm03as8o7dmsb30.apps.googleusercontent.com" id="g_id_onload"></div><div data-role="toast-container" style="position: fixed; z-index: 160; right: 0px; bottom: 0px; left: 0px;"></div></body></html>
